# %% [markdown]
# # Word alignment using [awesome-align](https://github.com/neulab/awesome-align)
#
#
# ### Prepare src-tgt to the correct format
#
# "Inputs should be *tokenized* and each line is a source language sentence and its target language translation, separated by (`|||`)"

# %%
def read_output_df(dataset, perturb_type, beam, replacement_strategy, analyse_feature=True, 
                   ignore_case=False, no_of_replacements=1, chunk_max_length=1, spacy_model=None, 
                   w2v_model=None, use_alignment=False, winoMT=False, ref_available=False):
    if winoMT:
        path_prefix = "output/winoMT_asmetric/wmt19_winoMT_perturbed"
        output_df = pd.read_csv('output/winoMT_asmetric/wmt19_winoMT_perturbed_format.csv', index_col=0)  
    else:
        if no_of_replacements == 1:
            path_prefix = f"output/{dataset}/{replacement_strategy}/beam{beam}_perturb{perturb_type}/seed0/translations"
        else:
            path_prefix = f"output/{dataset}/{replacement_strategy}/beam{beam}_perturb{perturb_type}/seed0/translations_5replacements"

        output_df = pd.read_csv(f"{path_prefix}.csv", index_col=0)

        # Join to get the translation of the original sentences as well
        output_df = output_df.join(pd.read_csv(
            f"output/{dataset}/{replacement_strategy}/beam{beam}_perturbNone/seed0/translations.csv", index_col=0
        )['OriginalSRC-Trans'])
        
    
    # Convert columns with sentences to str type
    cols = ['SRC', 'REF', 'SRC_perturbed', 'SRC_perturbed-Trans', 'OriginalSRC-Trans']
    if not ref_available:
        cols.remove('REF')
    output_df[cols] = output_df[cols].astype(str)
    
    if ignore_case:
        output_df[cols] = output_df[cols].applymap(lambda x: x.lower())
    
    # Reorder the columns
    if winoMT:
        cols = ['SRC', 'REF', 'original_word', 'perturbed_word', 'SRC_perturbed', 'OriginalSRC-Trans', 'SRC_perturbed-Trans', 'Bias_sample']
    elif no_of_replacements == 1:
        cols = ['SRC', 'REF', 'original_word', 'perturbed_word', 'SRC_perturbed', 'OriginalSRC-Trans', 'SRC_perturbed-Trans']
    else:
        cols = ['SRC_index', 'SRC', 'REF', 'original_word', 'perturbed_word', 'SRC_perturbed', 'OriginalSRC-Trans', 'SRC_perturbed-Trans']
    if not ref_available:
        cols.remove('REF')
    output_df = output_df[cols]
    
    if analyse_feature:
        print(f"Original df shape: {output_df.shape}")
        output_df = output_df.dropna()
        print(f"After dropping none-perturbed sentences: {output_df.dropna().shape}")
        
        if replacement_strategy == 'word2vec_similarity':
            # SRC difference is the number of occurances of the word we perturb
            output_df["SRC-edit_distance"] = output_df.apply(lambda x: nltk.word_tokenize(x['SRC']).count(x['original_word']), axis=1)
        else:
            output_df["SRC-edit_distance"] = 1
        output_df['Trans-edit_distance'] =  output_df.apply(
            lambda x: levenshtein(nltk.word_tokenize(x['OriginalSRC-Trans']), nltk.word_tokenize(x['SRC_perturbed-Trans'])), axis=1)
        output_df["#TransChanges-#SrcChanges"] = output_df['Trans-edit_distance'] - output_df['SRC-edit_distance']
        
        output_df["#TransChanges-#SrcChanges/SentenceLength"] = (output_df['Trans-edit_distance'] - output_df['SRC-edit_distance']) / output_df['SRC'].apply(lambda x: len(nltk.word_tokenize(x)))
        
        output_df["ChangesSpread/SentenceLength"] = output_df.apply(
            lambda x: changes_spread(x['SRC_perturbed-Trans'], x['OriginalSRC-Trans']), axis=1)
        
        
        output_df["OriginalSRC-Trans"], output_df['SRC_perturbed-Trans'], \
        output_df['TwoChunksChanged'],  output_df['ChunkDistance'], \
        output_df["is_same_subtree"], output_df['changes_similarity'] = zip(*output_df.apply(
            lambda x: two_chunk_changed(
                x['SRC_perturbed-Trans'], 
                x['OriginalSRC-Trans'], 
                chunk_max_length=chunk_max_length, 
                spacy_model=spacy_model,
                w2v_model=w2v_model), 
            axis=1))    
        
        
        if use_alignment:
            # In the case where two changes occurs and the two similarities is calculated, 
            # find out which change is due to the perturbation
            output_df['perturbed_trans_alignment'] = load_alignment(path_prefix)
            output_df['changes_similarity'] = output_df.apply(
                lambda x: add_reason_of_change(
                    alignment=x['perturbed_trans_alignment'],
                    changes=x['changes_similarity'],
                    perturbed_src_word=x['perturbed_word']
                ),
                axis=1
            )
            
            if spacy_model is not None:
                # Add POS tagging of the not-perturbed change
                output_df['not_perturbed_TGT_change_type'] = output_df['changes_similarity'].apply(
                    lambda x: pos_tag_not_perturbed_change(x, spacy_model))
            
        
        
        if no_of_replacements > 1:
            print(output_df.columns)
            additional_col_1 = output_df.groupby(by="SRC_index", axis=0)[['Trans-edit_distance', '#TransChanges-#SrcChanges']].std()
            additional_col_2 = output_df.groupby(by="SRC_index", axis=0)[['TwoChunksChanged']].sum()
            
            output_df = output_df.join(additional_col_1, rsuffix='--SD')
            output_df = output_df.join(additional_col_2, rsuffix='--total')
        
    return output_df

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import gensim
import gensim.downloader as api
from gensim.models.fasttext import load_facebook_model
import random
from difflib import SequenceMatcher
from scipy import stats
import sacrebleu
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats


perturb_type = 'content'
dataset = f'masked_covost2_for_en2de'  # 'MuST-SHE-en2fr' 'IWSLT15-en2vi' 'wmt19-newstest2019-en2de'
beam = 5
replacement_strategy = 'masking_language_model'
no_of_replacements = 5
ignore_case = False  # Only Europarls needs ignore case
chunk_max_length=1
spacy_model = None
# Loading these models in is time consuming
# de_model = load_facebook_model("data/cc.de.300.bin").wv
# vi_model = load_facebook_model("data/cc.vi.300.bin").wv

# # This overwrite the above params
# winoMT = True
# perturb_type = 'pronoun'
# no_of_replacements = 1

winoMT=False

output = read_output_df(dataset=dataset, perturb_type=perturb_type, beam=beam, 
                        replacement_strategy=replacement_strategy, ignore_case=ignore_case,
                        no_of_replacements=no_of_replacements, chunk_max_length=chunk_max_length,
                        spacy_model=spacy_model, analyse_feature=False)

output.head()
# Out:
#    SRC_index                                             SRC original_word  \
# 0          0  So the family will need to relearn everything.          need
# 0          0  So the family will need to relearn everything.          need
# 0          0  So the family will need to relearn everything.          need
# 0          0  So the family will need to relearn everything.          need
# 0          0  So the family will need to relearn everything.          need
#
#   perturbed_word                                      SRC_perturbed  \
# 0           have     So the family will have to relearn everything.
# 0            try      So the family will try to relearn everything.
# 0           want     So the family will want to relearn everything.
# 0       continue  So the family will continue to relearn everyth...
# 0            get      So the family will get to relearn everything.
#
#                                 OriginalSRC-Trans  \
# 0  Also wird die Familie alles neu lernen müssen.
# 0  Also wird die Familie alles neu lernen müssen.
# 0  Also wird die Familie alles neu lernen müssen.
# 0  Also wird die Familie alles neu lernen müssen.
# 0  Also wird die Familie alles neu lernen müssen.
#
#                                  SRC_perturbed-Trans
# 0     Also wird die Familie alles neu lernen müssen.
# 0  Also wird die Familie versuchen, alles neu zu ...
# 0     Also wird die Familie alles neu lernen wollen.
# 0  Also wird die Familie weiterhin alles neu lernen.
# 0            Also wird die Familie alles neu lernen.

# %%
if winoMT:
    path_prefix = "output/winoMT_asmetric/wmt19_winoMT_perturbed"
elif no_of_replacements == 1:
    path_prefix = f"output/{dataset}/{replacement_strategy}/beam{beam}_perturb{perturb_type}/seed0/translations"
else:
    path_prefix = f"output/{dataset}/{replacement_strategy}/beam{beam}_perturb{perturb_type}/seed0/translations_5replacements"
        
output_df_path = f"{path_prefix}_reformatted.txt"

with open(output_df_path, 'w') as file:
    for row in output.iterrows():
        tokenized_src = ' '.join(nltk.word_tokenize(row[1][f'SRC_perturbed']))
        tokenized_tgt = ' '.join(nltk.word_tokenize(row[1][f'SRC_perturbed-Trans']))
        file.write(f"{tokenized_src} ||| {tokenized_tgt}\n")

# %% [markdown]
# ### Load in the alignments

# %%
with open(f"{path_prefix}_word_alignment.txt") as f:
    lines = [line.rstrip() for line in f]
  
print(lines)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 with open(f"{path_prefix}_word_alignment.txt") as f:
#       2     lines = [line.rstrip() for line in f]
#       4 print(lines)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/wmt19-newstest2019-en2de/masking_language_model/beam5_perturbverb/seed0/translations_5replacements_word_alignment.txt'

# %%
translation_alignment = []
for line in lines:
    word_pairs = line.split()
    word_pairs = [word_pair.split('<sep>') for word_pair in word_pairs]
    translation_alignment.append(word_pairs)

# %%
translation_alignment
# Out:
# [[['Welsh', 'Welsh'],
#   ['was', 'hatte'],
#   ['worried', 'Angst'],
#   ["about'looking", ','],
#   ['like', 'wie'],
#   ['muppets', 'Muppets'],
#   ["'", "''"]],
#  [['Welsh', 'Welsh'],
#   ['is', 'macht'],
#   ['worried', 'Sorgen'],
#   ["about'looking", ','],
#   ['like', 'wie'],
#   ['muppets', 'Muppets'],
#   ["'", "''"]],
#  [['Welshman', 'Waliser'],
#   ['worried', 'besorgt'],
#   ["about'looking", 'über'],
#   ["about'looking", 'Aussehen'],
#   ['like', 'wie'],
#   ['muppets', 'Muppets'],
#   ["'", "''"]],
#  [['Welsh', 'Waliser'],
#   ['were', 'machten'],
#   ['worried', 'Sorgen'],
#   ["about'looking", ','],
#   ['like', 'wie'],
#   ['muppets', 'Muppets'],
#   ["'", "''"]],
#  [['Welsh', 'Waliser'],
#   [',', ','],
#   ['worried', 'Sorge'],
#   ['worried', 'Waliser'],
#   ["about'looking", '``'],
#   ["about'looking", 'auszusehen'],
#   ['like', 'wie'],
#   ['muppets', 'Muppets'],
#   ["'", "''"]],
#  [['There', 'herrscht'],
#   ['is', 'herrscht'],
#   ['consternation', 'Bestürzung'],
#   ['among', 'Unter'],
#   ['some', 'einigen'],
#   ['AMs', 'AMs'],
#   ['at', 'über'],
#   ['a', 'einen'],
#   ['suggestion', 'Vorschlag'],
#   ['their', 'ihren'],
#   ['title', 'Titel'],
#   ['should', 'zu'],
#   ['change', 'ändern'],
#   ['to', 'in'],
#   ['MWPs', 'MWPs'],
#   ['(', '('],
#   ['MPs', 'Abgeordnete'],
#   ['of', 'des'],
#   ['Welsh', 'walisischen'],
#   ['Parliament', 'Parlaments'],
#   [')', ')'],
#   ['.', '.']],
#  [['There', 'herrscht'],
#   ['is', 'herrscht'],
#   ['consternation', 'Bestürzung'],
#   ['among', 'Unter'],
#   ['some', 'einigen'],
#   ['AMs', 'AMs'],
#   ['at', 'über'],
#   ['a', 'einen'],
#   ['suggestion', 'Vorschlag'],
#   ['their', 'ihren'],
#   ['title', 'Titel'],
#   ['should', 'zu'],
#   ['change', 'ändern'],
#   ['to', 'in'],
#   ['MWPs', 'MWPs'],
#   ['(', '('],
#   ['Deputies', 'Deputies'],
#   ['of', 'of'],
#   ['the', 'the'],
#   ['Welsh', 'Welsh'],
#   ['Parliament', 'Parliament'],
#   [')', ')'],
#   ['.', '.']],
#  [['There', 'herrscht'],
#   ['is', 'herrscht'],
#   ['consternation', 'Bestürzung'],
#   ['among', 'Unter'],
#   ['some', 'einigen'],
#   ['AMs', 'AMs'],
#   ['at', 'über'],
#   ['a', 'einen'],
#   ['suggestion', 'Vorschlag'],
#   ['their', 'ihren'],
#   ['title', 'Titel'],
#   ['should', 'zu'],
#   ['change', 'ändern'],
#   ['to', 'in'],
#   ['MWPs', 'MWPs'],
#   ['(', '('],
#   ['Presidents', 'Präsidenten'],
#   ['of', 'des'],
#   ['Welsh', 'walisischen'],
#   ['Parliament', 'Parlaments'],
#   [')', ')'],
#   ['.', '.']],
#  [['There', 'herrscht'],
#   ['is', 'herrscht'],
#   ['consternation', 'Bestürzung'],
#   ['among', 'Unter'],
#   ['some', 'einigen'],
#   ['AMs', 'AMs'],
#   ['at', 'über'],
#   ['a', 'einen'],
#   ['suggestion', 'Vorschlag'],
#   ['their', 'ihren'],
#   ['title', 'Titel'],
#   ['should', 'zu'],
#   ['change', 'ändern'],
#   ['to', 'in'],
#   ['MWPs', 'MWPs'],
#   ['(', '('],
#   ['Representatives', 'Representatives'],
#   ['of', 'of'],
#   ['the', 'the'],
#   ['Welsh', 'Welsh'],
#   ['Parliament', 'Parliament'],
#   [')', ')'],
#   ['.', '.']],
#  [['There', 'herrscht'],
#   ['is', 'herrscht'],
#   ['consternation', 'Bestürzung'],
#   ['among', 'Unter'],
#   ['some', 'einigen'],
#   ['AMs', 'AMs'],
#   ['at', 'über'],
#   ['a', 'einen'],
#   ['suggestion', 'Vorschlag'],
#   ['their', 'ihren'],
#   ['title', 'Titel'],
#   ['should', 'zu'],
#   ['change', 'ändern'],
#   ['to', 'in'],
#   ['MWPs', 'MWPs'],
#   ['(', '('],
#   ['representatives', 'Vertreter'],
#   ['of', 'des'],
#   ['Welsh', 'walisischen'],
#   ['Parliament', 'Parlaments'],
#   [')', ')'],
#   ['.', '.']],
#  [['It', 'Sie'],
#   ['arisen', 'entstand'],
#   ['because', 'aufgrund'],
#   ['of', 'von'],
#   ['proposals', 'Vorschlägen'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['the', 'den'],
#   ['name', 'Namen'],
#   ['of', 'der'],
#   ['assembly', 'Versammlung'],
#   ['to', 'in'],
#   ['the', 'das'],
#   ['Welsh', 'walisische'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['It', 'Sie'],
#   ['arisen', 'entstand'],
#   ['because', 'aufgrund'],
#   ['of', 'von'],
#   ['attempts', 'Versuchen'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['the', 'den'],
#   ['name', 'Namen'],
#   ['of', 'der'],
#   ['assembly', 'Versammlung'],
#   ['to', 'in'],
#   ['the', 'das'],
#   ['Welsh', 'walisische'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['It', 'Sie'],
#   ['arisen', 'entstand'],
#   ['because', 'aufgrund'],
#   ['of', 'des'],
#   ['pressure', 'Drucks'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['the', 'den'],
#   ['name', 'Namen'],
#   ['of', 'der'],
#   ['assembly', 'Versammlung'],
#   ['to', 'in'],
#   ['the', 'das'],
#   ['Welsh', 'walisische'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['It', 'Sie'],
#   ['arisen', 'entstand'],
#   ['because', 'aufgrund'],
#   ['of', 'von'],
#   ['calls', 'Forderungen'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['the', 'den'],
#   ['name', 'Namen'],
#   ['of', 'der'],
#   ['assembly', 'Versammlung'],
#   ['to', 'in'],
#   ['the', 'das'],
#   ['Welsh', 'walisische'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['It', 'Sie'],
#   ['arisen', 'entstand'],
#   ['because', 'aufgrund'],
#   ['of', 'von'],
#   ['demands', 'Forderungen'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['the', 'den'],
#   ['name', 'Namen'],
#   ['of', 'der'],
#   ['assembly', 'Versammlung'],
#   ['to', 'in'],
#   ['the', 'das'],
#   ['Welsh', 'walisische'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['across', 'auf'],
#   ['the', 'der'],
#   ['political', 'politischen'],
#   ['arena', 'Bühne'],
#   ['are', 'sind'],
#   ['worried', 'besorgt'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['invite', 'zu'],
#   ['invite', 'führen'],
#   ['ridicule', 'Spott'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['across', 'auf'],
#   ['the', 'der'],
#   ['political', 'politischen'],
#   ['scene', 'Bühne'],
#   ['are', 'sind'],
#   ['worried', 'besorgt'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['invite', 'zu'],
#   ['invite', 'führen'],
#   ['ridicule', 'Spott'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['across', 'im'],
#   ['the', 'gesamten'],
#   ['political', 'politischen'],
#   ['system', 'System'],
#   ['are', 'sind'],
#   ['worried', 'besorgt'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['invite', 'zu'],
#   ['invite', 'führen'],
#   ['ridicule', 'Spott'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['across', 'in'],
#   ['the', 'der'],
#   ['political', 'politischen'],
#   ['world', 'Welt'],
#   ['are', 'sind'],
#   ['worried', 'besorgt'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['invite', 'zu'],
#   ['invite', 'führen'],
#   ['ridicule', 'Spott'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['across', 'in'],
#   ['the', 'der'],
#   ['political', 'politischen'],
#   ['landscape', 'Landschaft'],
#   ['are', 'sind'],
#   ['worried', 'besorgt'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['invite', 'zu'],
#   ['invite', 'führen'],
#   ['ridicule', 'Spott'],
#   ['.', '.']],
#  [['One', 'Ein'],
#   ['Labour', 'Labour-Abgeordneter'],
#   ['AM', 'Labour-Abgeordneter'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Fraktion'],
#   ['was', 'sei'],
#   ['concerned', 'besorgt'],
#   ['``', '``'],
#   ['it', 'es'],
#   ['rhymes', 'reimt'],
#   ['with', 'auf'],
#   ['P', 'P'],
#   ['and', 'und'],
#   ['Pwp.', 'Pwp'],
#   ['Pwp.', '.']],
#  [['One', 'Ein'],
#   ['Labour', 'Labour-Abgeordneter'],
#   ['AM', 'Labour-Abgeordneter'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Fraktion'],
#   ['was', 'sei'],
#   ['concerned', 'besorgt'],
#   ['``', '``'],
#   ['it', 'es'],
#   ['rhymes', 'reimt'],
#   ['with', 'auf'],
#   ['B', 'B'],
#   ['and', 'und'],
#   ['Pwp.', 'Pwp']],
#  [['One', 'Ein'],
#   ['Labour', 'Labour-Abgeordneter'],
#   ['AM', 'Labour-Abgeordneter'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Gruppe'],
#   ['was', 'sei'],
#   ['concerned', 'besorgt'],
#   ['``', '``'],
#   ['it', 'es'],
#   ['rhymes', 'reimt'],
#   ['with', 'auf'],
#   ['Pop', 'Pop'],
#   ['and', 'und'],
#   ['Pwp.', 'Pwp'],
#   ['Pwp.', '.']],
#  [['One', 'Ein'],
#   ['Labour', 'Labour-Abgeordneter'],
#   ['AM', 'Labour-Abgeordneter'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Fraktion'],
#   ['was', 'sei'],
#   ['concerned', 'besorgt'],
#   ['``', '``'],
#   ['it', 'es'],
#   ['rhymes', 'reimt'],
#   ['with', 'auf'],
#   ['Pig', 'Schwein'],
#   ['and', 'und'],
#   ['Pwp.', 'Pwp']],
#  [['One', 'Ein'],
#   ['Labour', 'Labour-Abgeordneter'],
#   ['AM', 'Labour-Abgeordneter'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Fraktion'],
#   ['was', 'sei'],
#   ['concerned', 'besorgt'],
#   ['``', '``'],
#   ['it', 'es'],
#   ['rhymes', 'reimt'],
#   ['with', 'auf'],
#   ['C', 'C'],
#   ['and', 'und'],
#   ['Pwp.', 'Pwp']],
#  [['For', 'Für'],
#   ['readers', 'Leser'],
#   ['outside', 'außerhalb'],
#   ['of', 'von'],
#   ['Wales', 'Wales'],
#   [':', ':'],
#   ['In', 'Auf'],
#   ['Welsh', 'Walisisch'],
#   ['it', 'es'],
#   ['means', 'bedeutet'],
#   ['daft', 'dumm'],
#   ['and', 'und'],
#   ['pwp', 'pwp'],
#   ['means', 'bedeutet'],
#   ['poo', 'poo'],
#   ['.', '.']],
#  [['For', 'Für'],
#   ['readers', 'Leser'],
#   ['outside', 'außerhalb'],
#   ['of', 'von'],
#   ['Wales', 'Wales'],
#   [':', ':'],
#   ['In', 'Auf'],
#   ['Welsh', 'Walisisch'],
#   ['he', 'er'],
#   ['means', 'bedeutet'],
#   ['daft', 'dumm'],
#   ['and', 'und'],
#   ['pwp', 'pwp'],
#   ['means', 'bedeutet'],
#   ['poo', 'poo'],
#   ['.', '.']],
#  [['For', 'Für'],
#   ['readers', 'Leser'],
#   ['outside', 'außerhalb'],
#   ['of', 'von'],
#   ['Wales', 'Wales'],
#   [':', ':'],
#   ['In', 'Auf'],
#   ['Welsh', 'Walisisch'],
#   ['means', 'bedeutet'],
#   ['daft', 'doof'],
#   ['and', 'und'],
#   ['pwp', 'pwp'],
#   ['means', 'bedeutet'],
#   ['poo', 'poo'],
#   ['.', '.']],
#  [['For', 'Für'],
#   ['readers', 'Leser'],
#   ['outside', 'außerhalb'],
#   ['of', 'von'],
#   ['Wales', 'Wales'],
#   [':', ':'],
#   ['In', 'Walisisch'],
#   ['Welsh', 'Walisisch'],
#   ['means', 'bedeutet'],
#   ['daft', 'dumm'],
#   ['and', 'und'],
#   ['pwp', 'pwp'],
#   ['means', 'bedeutet'],
#   ['poo', 'poo'],
#   ['.', '.']],
#  [['For', 'Für'],
#   ['readers', 'Leser'],
#   ['outside', 'außerhalb'],
#   ['of', 'von'],
#   ['Wales', 'Wales'],
#   [':', ':'],
#   ['In', 'Auf'],
#   ['Welsh', 'Walisisch'],
#   ['p', 'p'],
#   ['daft', 'dumm'],
#   ['and', 'und'],
#   ['pwp', 'pwp'],
#   ['means', 'bedeutet'],
#   ['poo', 'poo'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Plaid', 'karierter'],
#   ['AM', 'AM'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['the', 'die'],
#   ['group', 'Gruppe'],
#   ['as', 'als'],
#   ['whole', 'Ganzes'],
#   ['was', 'sei'],
#   ['``', '``'],
#   ['not', 'nicht'],
#   ['happy', 'glücklich'],
#   ['and', 'und'],
#   ['has', 'habe'],
#   ['suicide', 'Selbstmord'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Plaid', 'Plaid'],
#   ['AM', 'AM'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['the', 'die'],
#   ['group', 'Gruppe'],
#   ['as', 'als'],
#   ['whole', 'Ganzes'],
#   ['was', 'sei'],
#   ['``', '``'],
#   ['not', 'nicht'],
#   ['happy', 'glücklich'],
#   ['and', 'und'],
#   ['has', 'habe'],
#   ['suggested', 'vorgeschlagen'],
#   ['closure', 'Schließung'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Plaid', 'karierter'],
#   ['AM', 'AM'],
#   ['said', 'sagte'],
#   ['the', 'die'],
#   ['group', 'Gruppe'],
#   ['as', 'als'],
#   ['whole', 'Ganzes'],
#   ['was', 'sei'],
#   ['``', '``'],
#   ['not', 'nicht'],
#   ['happy', 'glücklich'],
#   ['and', 'und'],
#   ['has', 'habe'],
#   ['otherwise', 'etwas'],
#   ['otherwise', 'anderes'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Plaid', 'karierter'],
#   ['AM', 'AM'],
#   ['said', 'sagte'],
#   ['the', 'die'],
#   ['group', 'Gruppe'],
#   ['as', 'als'],
#   ['whole', 'Ganzes'],
#   ['was', 'sei'],
#   ['``', '``'],
#   ['not', 'nicht'],
#   ['happy', 'glücklich'],
#   ['and', 'und'],
#   ['has', 'habe'],
#   ['suggested', 'vorgeschlagen'],
#   ['this', 'dies'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Plaid', 'karierter'],
#   ['AM', 'AM'],
#   ['said', 'sagte'],
#   ['the', 'die'],
#   ['group', 'Gruppe'],
#   ['as', 'als'],
#   ['whole', 'Ganzes'],
#   ['was', 'sei'],
#   ['``', '``'],
#   ['not', 'nicht'],
#   ['happy', 'glücklich'],
#   ['and', 'und'],
#   ['has', 'habe'],
#   ['suggested', 'eine'],
#   ['suggested', 'vorgeschlagen'],
#   ['reconciliation', 'Versöhnung'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Welsh', 'walisischer'],
#   ['Conservative', 'Konservativer'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Fraktion'],
#   ['was', 'stehe'],
#   ['``', '``'],
#   ['open', 'aufgeschlossen'],
#   ['minded', 'aufgeschlossen'],
#   ['``', '``'],
#   ['the', 'der'],
#   ['name', 'Namenswahl'],
#   ['choice', 'Namenswahl'],
#   [',', ','],
#   ['but', 'aber'],
#   ['noted', 'merkte'],
#   ['it', 'es'],
#   ['was', 'sei'],
#   ['a', 'ein'],
#   ['short', 'kurzer'],
#   ['verbal', 'verbaler'],
#   ['hop', 'Sprung'],
#   ['from', 'von'],
#   ['MWP', 'MWP'],
#   ['to', 'zu'],
#   ['Muppet', 'Muppet'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Welsh', 'walisischer'],
#   ['Conservative', 'Konservativer'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Gruppe'],
#   ['was', 'sei'],
#   ['``', '``'],
#   ['open', 'aufgeschlossen'],
#   ['minded', 'aufgeschlossen'],
#   ['about', 'gegenüber'],
#   ['the', 'dem'],
#   ['nameplate', 'Namensschild'],
#   [',', ','],
#   ['but', 'aber'],
#   ['noted', 'merkte'],
#   ['it', 'es'],
#   ['was', 'sei'],
#   ['a', 'ein'],
#   ['short', 'kurzer'],
#   ['verbal', 'verbaler'],
#   ['hop', 'Sprung'],
#   ['from', 'von'],
#   ['MWP', 'MWP'],
#   ['to', 'zu'],
#   ['Muppet', 'Muppet'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Welsh', 'walisischer'],
#   ['Conservative', 'Konservativer'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Gruppe'],
#   ['was', 'stehe'],
#   ['``', '``'],
#   ['open', 'aufgeschlossen'],
#   ['minded', 'aufgeschlossen'],
#   ['``', '``'],
#   ['the', 'dem'],
#   ['name', 'Namenswettbewerb'],
#   ['contest', 'Namenswettbewerb'],
#   [',', ','],
#   ['but', 'aber'],
#   ['noted', 'merkte'],
#   ['it', 'es'],
#   ['was', 'um'],
#   ['a', 'einen'],
#   ['short', 'kurzen'],
#   ['verbal', 'verbalen'],
#   ['hop', 'Sprung'],
#   ['from', 'von'],
#   ['MWP', 'MWP'],
#   ['to', 'zu'],
#   ['Muppet', 'Muppet'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Welsh', 'walisischer'],
#   ['Conservative', 'Konservativer'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Gruppe'],
#   ['was', 'sei'],
#   ['``', '``'],
#   ['open', 'aufgeschlossen'],
#   ['minded', 'aufgeschlossen'],
#   ['about', 'gegenüber'],
#   ['the', 'der'],
#   ['name', 'Namenswahl'],
#   ['selection', 'Namenswahl'],
#   [',', ','],
#   ['but', 'aber'],
#   ['noted', 'merkte'],
#   ['it', 'es'],
#   ['was', 'sei'],
#   ['a', 'ein'],
#   ['short', 'kurzer'],
#   ['verbal', 'verbaler'],
#   ['hop', 'Sprung'],
#   ['from', 'von'],
#   ['MWP', 'MWP'],
#   ['to', 'zu'],
#   ['Muppet', 'Muppet'],
#   ['.', '.']],
#  [['A', 'Ein'],
#   ['Welsh', 'walisischer'],
#   ['Conservative', 'Konservativer'],
#   ['said', 'sagte'],
#   ['said', ','],
#   ['his', 'seine'],
#   ['group', 'Gruppe'],
#   ['was', 'sei'],
#   ['``', '``'],
#   ['open', 'aufgeschlossen'],
#   ['minded', 'aufgeschlossen'],
#   ['``', '``'],
#   ['about', 'gegenüber'],
#   ['the', 'dem'],
#   ['name', 'Namen'],
#   ['itself', 'selbst'],
#   [',', ','],
#   ['but', 'aber'],
#   ['noted', 'merkte'],
#   ['it', 'es'],
#   ['was', 'sei'],
#   ['a', 'ein'],
#   ['short', 'kurzer'],
#   ['verbal', 'verbaler'],
#   ['hop', 'Sprung'],
#   ['from', 'von'],
#   ['MWP', 'MWP'],
#   ['to', 'zu'],
#   ['Muppet', 'Muppet'],
#   ['.', '.']],
#  [['In', 'In'],
#   ['this', 'diesem'],
#   ['context', 'Zusammenhang'],
#   ['The', 'der'],
#   ['Welsh', 'walisische'],
#   ['vowel', 'Vokal'],
#   ['w', 'w'],
#   ['is', 'wird'],
#   ['pronounced', 'ausgesprochen'],
#   ['similarly', 'ähnlich'],
#   ['to', 'wie'],
#   ['the', 'die'],
#   ['English', 'englische'],
#   ['pronunciation', 'Aussprache'],
#   ['of', 'des'],
#   ['letter', 'Buchstabens'],
#   ['u', 'u'],
#   ['.', '.']],
#  [['In', 'In'],
#   ['this', 'diesem'],
#   ['context', 'Zusammenhang'],
#   ['The', 'das'],
#   ['Welsh', 'walisische'],
#   ['word', 'Wort'],
#   ['w', 'w'],
#   ['is', 'wird'],
#   ['pronounced', 'ausgesprochen'],
#   ['similarly', 'ähnlich'],
#   ['to', 'wie'],
#   ['the', 'die'],
#   ['English', 'englische'],
#   ['pronunciation', 'Aussprache'],
#   ['of', 'des'],
#   ['letter', 'Buchstabens'],
#   ['u', 'u'],
#   ['.', '.']],
#  [['In', 'In'],
#   ['this', 'diesem'],
#   ['context', 'Zusammenhang'],
#   ['The', 'die'],
#   ['Welsh', 'walisische'],
#   ['pronunciation', 'Aussprache'],
#   ['w', 'w'],
#   ['is', 'wird'],
#   ['pronounced', 'ausgesprochen'],
#   ['similarly', 'ähnlich'],
#   ['to', 'wie'],
#   ['the', 'die'],
#   ['English', 'englische'],
#   ['pronunciation', 'Aussprache'],
#   ['of', 'des'],
#   ['letter', 'Buchstabens'],
#   ['u', 'u'],
#   ['.', '.']],
#  [['In', 'In'],
#   ['this', 'diesem'],
#   ['context', 'Zusammenhang'],
#   ['The', 'der'],
#   ['Welsh', 'walisische'],
#   ['sound', 'Klang'],
#   ['w', 'w'],
#   ['is', 'wird'],
#   ['pronounced', 'ausgesprochen'],
#   ['similarly', 'ähnlich'],
#   ['to', 'wie'],
#   ['the', 'die'],
#   ['English', 'englische'],
#   ['pronunciation', 'Aussprache'],
#   ['of', 'des'],
#   ['letter', 'Buchstabens'],
#   ['u', 'u'],
#   ['.', '.']],
#  [['In', 'In'],
#   ['this', 'diesem'],
#   ['context', 'Zusammenhang'],
#   ['The', 'das'],
#   ['Welsh', 'walisische'],
#   ['symbol', 'Symbol'],
#   ['w', 'w'],
#   ['is', 'wird'],
#   ['pronounced', 'ausgesprochen'],
#   ['similarly', 'ähnlich'],
#   ['to', 'wie'],
#   ['the', 'die'],
#   ['English', 'englische'],
#   ['pronunciation', 'Aussprache'],
#   ['of', 'des'],
#   ['letter', 'Buchstabens'],
#   ['u', 'u'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['Assembly', 'Versammlungskommission'],
#   ['Commission', 'Versammlungskommission'],
#   [',', ','],
#   ['which', 'die'],
#   ['currently', 'derzeit'],
#   ['drafting', 'ausarbeitet'],
#   ['legislation', 'Gesetzesentwurf'],
#   ['to', 'zur'],
#   ['introduce', 'Einführung'],
#   ['the', 'der'],
#   ['name', 'Namensänderung'],
#   ['amendment', 'Gesetzesentwurf'],
#   [',', ','],
#   ['said', 'sagte'],
#   [':', ':'],
#   ['``', '``'],
#   ['The', 'Die'],
#   ['final', 'endgültige'],
#   ['decision', 'Entscheidung'],
#   ['on', 'über'],
#   ['any', 'die'],
#   ['descriptors', 'Beschreibung'],
#   ['of', 'dessen'],
#   ['what', 'wie'],
#   ['Assembly', 'Versammlung'],
#   ['Members', 'Mitglieder'],
#   ['are', 'werden'],
#   ['called', 'genannt'],
#   ['course', 'natürlich'],
#   ['be', 'liegt'],
#   ['for', 'bei'],
#   ['the', 'den'],
#   ['members', 'Mitgliedern'],
#   ['themselves.', 'selbst'],
#   ['themselves.', '.']],
#  [['The', 'Die'],
#   ['Assembly', 'Versammlungskommission'],
#   ['Commission', 'Versammlungskommission'],
#   [',', ','],
#   ['which', 'die'],
#   ['currently', 'derzeit'],
#   ['drafting', 'ausarbeitet'],
#   ['legislation', 'Gesetzesentwurf'],
#   ['to', 'zur'],
#   ['introduce', 'Einführung'],
#   ['the', 'des'],
#   ['name', 'Namens'],
#   ['Assembly', 'Versammlung'],
#   [',', ','],
#   ['said', 'sagte'],
#   [':', ':'],
#   ['``', '``'],
#   ['The', 'Die'],
#   ['final', 'endgültige'],
#   ['decision', 'Entscheidung'],
#   ['on', 'über'],
#   ['any', 'die'],
#   ['descriptors', 'Beschreibung'],
#   ['of', 'dessen'],
#   ['what', 'was'],
#   ['Assembly', 'Versammlungsmitglieder'],
#   ['Members', 'Versammlungsmitglieder'],
#   ['are', 'werden'],
#   ['called', 'genannt'],
#   ['course', 'natürlich'],
#   ['be', 'liegt'],
#   ['for', 'bei'],
#   ['the', 'den'],
#   ['members', 'Mitgliedern'],
#   ['themselves.', 'selbst'],
#   ['themselves.', '.']],
#  [['The', 'Die'],
#   ['Assembly', 'Versammlungskommission'],
#   ['Commission', 'Versammlungskommission'],
#   [',', ','],
#   ['which', 'die'],
#   ['currently', 'derzeit'],
#   ['drafting', 'ausarbeitet'],
#   ['legislation', 'Gesetzesentwurf'],
#   ['to', 'zur'],
#   ['introduce', 'Einführung'],
#   ['the', 'des'],
#   ['name', 'Namensgesetzes'],
#   ['bill', 'Namensgesetzes'],
#   [',', ','],
#   ['said', 'sagte'],
#   [':', ':'],
#   ['``', '``'],
#   ['The', 'Die'],
#   ['final', 'endgültige'],
#   ['decision', 'Entscheidung'],
#   ['on', 'über'],
#   ['any', 'die'],
#   ['descriptors', 'Beschreibung'],
#   ['of', 'dessen'],
#   ['what', 'wie'],
#   ['Assembly', 'Versammlung'],
#   ['Members', 'Mitglieder'],
#   ['are', 'werden'],
#   ['called', 'genannt'],
#   ['course', 'natürlich'],
#   ['be', 'liegt'],
#   ['for', 'bei'],
#   ['the', 'den'],
#   ['members', 'Mitgliedern'],
#   ['themselves.', 'selbst'],
#   ['themselves.', '.']],
#  [['The', 'Die'],
#   ['Assembly', 'Versammlungskommission'],
#   ['Commission', 'Versammlungskommission'],
#   [',', ','],
#   ['which', 'die'],
#   ['currently', 'derzeit'],
#   ['drafting', 'ausarbeitet'],
#   ['legislation', 'Gesetzesentwurf'],
#   ['to', 'zur'],
#   ['introduce', 'Einführung'],
#   ['the', 'der'],
#   ['name', 'Namenskonvention'],
#   ['convention', 'Namenskonvention'],
#   [',', ','],
#   ['said', 'sagte'],
#   [':', ':'],
#   ['``', '``'],
#   ['The', 'Die'],
#   ['final', 'endgültige'],
#   ['decision', 'Entscheidung'],
#   ['on', 'über'],
#   ['any', 'die'],
#   ['descriptors', 'Beschreibung'],
#   ['of', 'dessen'],
#   ['what', 'wie'],
#   ['Assembly', 'Versammlung'],
#   ['Members', 'Mitglieder'],
#   ['are', 'werden'],
#   ['called', 'genannt'],
#   ['course', 'natürlich'],
#   ['be', 'liegt'],
#   ['for', 'bei'],
#   ['the', 'den'],
#   ['members', 'Mitgliedern'],
#   ['themselves.', 'selbst'],
#   ['themselves.', '.']],
#  [['The', 'Die'],
#   ['Assembly', 'Versammlungskommission'],
#   ['Commission', 'Versammlungskommission'],
#   [',', ','],
#   ['which', 'die'],
#   ['currently', 'derzeit'],
#   ['drafting', 'ausarbeitet'],
#   ['legislation', 'Gesetzesentwurf'],
#   ['to', 'zur'],
#   ['introduce', 'Einführung'],
#   ['the', 'der'],
#   ['name', 'Namensänderungen'],
#   ['amendments', 'Namensänderungen'],
#   [',', ','],
#   ['said', 'sagte'],
#   [':', ':'],
#   ['``', '``'],
#   ['The', 'Die'],
#   ['final', 'endgültige'],
#   ['decision', 'Entscheidung'],
#   ['on', 'über'],
#   ['any', 'die'],
#   ['descriptors', 'Beschreibung'],
#   ['of', 'dessen'],
#   ['what', 'wie'],
#   ['Assembly', 'Versammlung'],
#   ['Members', 'Mitglieder'],
#   ['are', 'werden'],
#   ['called', 'genannt'],
#   ['course', 'natürlich'],
#   ['be', 'liegt'],
#   ['for', 'bei'],
#   ['the', 'den'],
#   ['members', 'Mitgliedern'],
#   ['themselves.', 'selbst'],
#   ['themselves.', '.']],
#  [['The', 'Der'],
#   ['Government', 'Government'],
#   ['of', 'of'],
#   ['Wales', 'Wales'],
#   ['Act', 'Act'],
#   ['2017', '2017'],
#   ['gave', 'gab'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['the', 'die'],
#   ['power', 'Befugnis'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['its', 'ihren'],
#   ['name', 'Namen'],
#   ['.', '.']],
#  [['The', 'Der'],
#   ['Government', 'Government'],
#   ['of', 'of'],
#   ['Wales', 'Wales'],
#   ['Act', 'Act'],
#   ['2017', '2017'],
#   ['gave', 'gab'],
#   ['the', 'der'],
#   ['Cardiff', 'Cardiff'],
#   ['assembly', 'Versammlung'],
#   ['the', 'die'],
#   ['power', 'Befugnis'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['its', 'ihren'],
#   ['name', 'Namen'],
#   ['.', '.']],
#  [['The', 'Der'],
#   ['Government', 'Government'],
#   ['of', 'of'],
#   ['Wales', 'Wales'],
#   ['Act', 'Act'],
#   ['2017', '2017'],
#   ['gave', 'gab'],
#   ['the', 'der'],
#   ['county', 'Bezirksversammlung'],
#   ['assembly', 'Bezirksversammlung'],
#   ['the', 'die'],
#   ['power', 'Befugnis'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['its', 'ihren'],
#   ['name', 'Namen'],
#   ['.', '.']],
#  [['The', 'Der'],
#   ['Government', 'Government'],
#   ['of', 'of'],
#   ['Wales', 'Wales'],
#   ['Act', 'Act'],
#   ['2017', '2017'],
#   ['gave', 'gab'],
#   ['the', 'der'],
#   ['general', 'Generalversammlung'],
#   ['assembly', 'Generalversammlung'],
#   ['the', 'die'],
#   ['power', 'Befugnis'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['its', 'ihren'],
#   ['name', 'Namen'],
#   ['.', '.']],
#  [['The', 'Der'],
#   ['Government', 'Government'],
#   ['of', 'of'],
#   ['Wales', 'Wales'],
#   ['Act', 'Act'],
#   ['2017', '2017'],
#   ['gave', 'gab'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['the', 'die'],
#   ['power', 'Befugnis'],
#   ['to', ','],
#   ['change', 'ändern'],
#   ['its', 'ihren'],
#   ['name', 'Namen'],
#   ['.', '.']],
#  [['In', 'Im'],
#   ['June', 'Juni'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['published', 'veröffentlichte'],
#   ['the', 'den'],
#   ['report', 'Bericht'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['proposals', 'Vorschlägen'],
#   ['which', 'die'],
#   ['found', 'fand'],
#   ['broad', 'breite'],
#   ['support', 'Unterstützung'],
#   ['for', 'für'],
#   ['calling', 'Einberufung'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['a', 'als'],
#   ['Welsh', 'walisisches'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['In', 'Im'],
#   ['June', 'Juni'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['published', 'veröffentlichte'],
#   ['the', 'die'],
#   ['findings', 'Ergebnisse'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['proposals', 'Vorschlägen'],
#   ['which', 'die'],
#   ['found', 'fanden'],
#   ['broad', 'breite'],
#   ['support', 'Unterstützung'],
#   ['for', 'für'],
#   ['calling', 'Einberufung'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['a', 'als'],
#   ['Welsh', 'walisisches'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['In', 'Im'],
#   ['June', 'Juni'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['published', 'veröffentlichte'],
#   ['the', 'die'],
#   ['reports', 'Berichte'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['proposals', 'Vorschlägen'],
#   ['which', 'die'],
#   ['found', 'fanden'],
#   ['broad', 'breite'],
#   ['support', 'Unterstützung'],
#   ['for', 'für'],
#   ['calling', 'Einberufung'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['a', 'als'],
#   ['Welsh', 'walisisches'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['In', 'Im'],
#   ['June', 'Juni'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['published', 'veröffentlichte'],
#   ['the', 'das'],
#   ['outcome', 'Ergebnis'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['proposals', 'Vorschlägen'],
#   ['which', 'die'],
#   ['found', 'fand'],
#   ['broad', 'breite'],
#   ['support', 'Unterstützung'],
#   ['for', 'für'],
#   ['calling', 'Einberufung'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['a', 'als'],
#   ['Welsh', 'walisisches'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['In', 'Im'],
#   ['June', 'Juni'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['published', 'veröffentlichte'],
#   ['the', 'den'],
#   ['Report', 'Bericht'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['proposals', 'Vorschlägen'],
#   ['which', 'die'],
#   ['found', 'fanden'],
#   ['broad', 'breite'],
#   ['support', 'Unterstützung'],
#   ['for', 'für'],
#   ['calling', 'Einberufung'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['a', 'als'],
#   ['Welsh', 'walisisches'],
#   ['Parliament', 'Parlament'],
#   ['.', '.']],
#  [['On', 'Hinsichtlich'],
#   ['matter', 'Hinsichtlich'],
#   ['of', 'des'],
#   ['the', 'der'],
#   ["AMs'title", 'AMs'],
#   ["AMs'title", 'Titels'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['favoured', 'favorisierte'],
#   ['either', 'entweder'],
#   ['Parliament', 'Parlamentsmitglieder'],
#   ['Members', 'Parlamentsmitglieder'],
#   ['or', 'oder'],
#   ['WMPs', 'WMPs'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'die'],
#   ['MWP', 'MWP-Option'],
#   ['option', 'MWP-Option'],
#   ['received', 'erhielt'],
#   ['the', 'die'],
#   ['most', 'meiste'],
#   ['support', 'Unterstützung'],
#   ['in', 'in'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['.', '.']],
#  [['On', 'Hinsichtlich'],
#   ['matter', 'Hinsichtlich'],
#   ['of', 'des'],
#   ['the', 'der'],
#   ["AMs'title", 'AMs'],
#   ["AMs'title", 'Titels'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['favoured', 'favorisierte'],
#   ['the', 'die'],
#   ['Parliament', 'Parlamentsmitglieder'],
#   ['Members', 'Parlamentsmitglieder'],
#   ['or', 'oder'],
#   ['WMPs', 'WMPs'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'die'],
#   ['MWP', 'MWP-Option'],
#   ['option', 'MWP-Option'],
#   ['received', 'erhielt'],
#   ['the', 'die'],
#   ['most', 'meiste'],
#   ['support', 'Unterstützung'],
#   ['in', 'in'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['.', '.']],
#  [['On', 'Hinsichtlich'],
#   ['matter', 'Hinsichtlich'],
#   ['of', 'des'],
#   ['the', 'der'],
#   ["AMs'title", 'AMs'],
#   ["AMs'title", 'Titels'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['favoured', 'favorisierte'],
#   ['Local', 'lokale'],
#   ['Parliament', 'Parlamentsmitglieder'],
#   ['Members', 'Parlamentsmitglieder'],
#   ['or', 'oder'],
#   ['WMPs', 'WMPs'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'die'],
#   ['MWP', 'MWP-Option'],
#   ['option', 'MWP-Option'],
#   ['received', 'erhielt'],
#   ['the', 'die'],
#   ['most', 'meiste'],
#   ['support', 'Unterstützung'],
#   ['in', 'in'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['.', '.']],
#  [['On', 'Hinsichtlich'],
#   ['matter', 'Hinsichtlich'],
#   ['of', 'des'],
#   ['the', 'der'],
#   ["AMs'title", 'AMs'],
#   ["AMs'title", 'Titels'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['favoured', 'favorisierte'],
#   ['Commonwealth', 'Commonwealth-Parlaments'],
#   ['Parliament', 'Commonwealth-Parlaments'],
#   ['Members', 'Mitglieder'],
#   ['or', 'oder'],
#   ['WMPs', 'WMPs'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'die'],
#   ['MWP', 'MWP-Option'],
#   ['option', 'MWP-Option'],
#   ['received', 'erhielt'],
#   ['the', 'die'],
#   ['most', 'meiste'],
#   ['support', 'Unterstützung'],
#   ['in', 'in'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['.', '.']],
#  [['On', 'Hinsichtlich'],
#   ['matter', 'Hinsichtlich'],
#   ['of', 'des'],
#   ['the', 'der'],
#   ["AMs'title", 'AMs'],
#   ["AMs'title", 'Titels'],
#   ['the', 'die'],
#   ['Commission', 'Kommission'],
#   ['favoured', 'favorisierte'],
#   ['European', 'Europäischen'],
#   ['Parliament', 'Parlaments'],
#   ['Members', 'Mitglieder'],
#   ['or', 'oder'],
#   ['WMPs', 'WMPs'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'die'],
#   ['MWP', 'MWP-Option'],
#   ['option', 'MWP-Option'],
#   ['received', 'erhielt'],
#   ['the', 'die'],
#   ['most', 'meiste'],
#   ['support', 'Unterstützung'],
#   ['in', 'in'],
#   ['a', 'einer'],
#   ['public', 'öffentlichen'],
#   ['consultation', 'Konsultation'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['are', 'schlagen'],
#   ['apparently', 'anscheinend'],
#   ['alternative', 'alternative'],
#   ['options', 'Optionen'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'der'],
#   ['struggle', 'Kampf'],
#   ['to', ','],
#   ['reach', 'erreichen'],
#   ['them', 'sie'],
#   ['could', 'könnte'],
#   ['be', 'bereiten'],
#   ['headache', 'Kopfzerbrechen'],
#   ['the', 'der'],
#   ['Officer', 'Vorsitzenden'],
#   ['Elin', 'Elin'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['who', 'der'],
#   ['is', 'wird'],
#   ['expected', 'erwartet'],
#   ['to', 'dass'],
#   ['submit', 'vorlegt'],
#   ['legislation', 'Gesetzesentwürfe'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['changes', 'Änderungen'],
#   ['within', 'innerhalb'],
#   ['weeks', 'Wochen'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['are', 'schlagen'],
#   ['apparently', 'anscheinend'],
#   ['alternative', 'alternative'],
#   ['options', 'Optionen'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'der'],
#   ['struggle', 'Kampf'],
#   ['to', ','],
#   ['reach', 'erreichen'],
#   ['these', 'diese'],
#   ['could', 'könnte'],
#   ['be', 'bereiten'],
#   ['headache', 'Kopfzerbrechen'],
#   ['the', 'der'],
#   ['Officer', 'Vorsitzenden'],
#   ['Elin', 'Elin'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['who', 'der'],
#   ['is', 'wird'],
#   ['expected', 'erwartet'],
#   ['to', 'dass'],
#   ['submit', 'vorlegt'],
#   ['legislation', 'Gesetzesentwürfe'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['changes', 'Änderungen'],
#   ['within', 'innerhalb'],
#   ['weeks', 'Wochen'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['are', 'schlagen'],
#   ['apparently', 'anscheinend'],
#   ['alternative', 'alternative'],
#   ['options', 'Optionen'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'der'],
#   ['struggle', 'Kampf'],
#   ['to', ','],
#   ['to', 'zu'],
#   ['reach', 'erreichen'],
#   ['those', 'diese'],
#   ['could', 'könnte'],
#   ['be', 'bereiten'],
#   ['headache', 'Kopfzerbrechen'],
#   ['the', 'der'],
#   ['Officer', 'Vorsitzenden'],
#   ['Elin', 'Elin'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['who', 'der'],
#   ['is', 'wird'],
#   ['expected', 'erwartet'],
#   ['to', 'dass'],
#   ['submit', 'vorlegt'],
#   ['legislation', 'Gesetzesentwürfe'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['changes', 'Änderungen'],
#   ['within', 'innerhalb'],
#   ['weeks', 'Wochen'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['are', 'schlagen'],
#   ['apparently', 'anscheinend'],
#   ['alternative', 'alternative'],
#   ['options', 'Optionen'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'der'],
#   ['struggle', 'Kampf'],
#   ['to', 'zu'],
#   ['reach', 'erreichen'],
#   ['one', 'eine'],
#   ['could', 'könnte'],
#   ['be', 'bereiten'],
#   ['headache', 'Kopfzerbrechen'],
#   ['the', 'der'],
#   ['Officer', 'Vorsitzenden'],
#   ['Elin', 'Elin'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['who', 'der'],
#   ['who', 'dass'],
#   ['is', 'wird'],
#   ['expected', 'erwartet'],
#   ['to', 'dass'],
#   ['submit', 'vorlegt'],
#   ['legislation', 'Gesetzesentwürfe'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['changes', 'Änderungen'],
#   ['within', 'innerhalb'],
#   ['weeks', 'Wochen'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['are', 'schlagen'],
#   ['apparently', 'anscheinend'],
#   ['alternative', 'alternative'],
#   ['options', 'Optionen'],
#   [',', ','],
#   ['but', 'aber'],
#   ['the', 'das'],
#   ['struggle', 'Ringen'],
#   ['to', 'um'],
#   ['reach', 'eine'],
#   ['agreement', 'Einigung'],
#   ['could', 'könnte'],
#   ['be', 'bereiten'],
#   ['headache', 'Kopfzerbrechen'],
#   ['the', 'der'],
#   ['Officer', 'Vorsitzenden'],
#   ['Elin', 'Elin'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['who', 'der'],
#   ['is', 'wird'],
#   ['expected', 'erwartet'],
#   ['to', 'dass'],
#   ['submit', 'vorlegt'],
#   ['legislation', 'Gesetzesentwürfe'],
#   ['on', 'zu'],
#   ['the', 'den'],
#   ['changes', 'Änderungen'],
#   ['within', 'innerhalb'],
#   ['weeks', 'Wochen'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['legislation', 'Gesetzesvorlage'],
#   ['on', 'Gesetzesvorlage'],
#   ['include', 'wird'],
#   ['other', 'weitere'],
#   ['changes', 'Änderungen'],
#   ['to', 'in'],
#   ['the', 'der'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['works', 'Arbeitsweise'],
#   [',', ','],
#   ['including', 'darunter'],
#   ['rules', 'Regeln'],
#   ['on', 'zur'],
#   ['disqualification', 'Disqualifikation'],
#   ['of', 'von'],
#   ['AMs', 'AMs'],
#   ['and', 'und'],
#   ['the', 'zur'],
#   ['design', 'Gestaltung'],
#   ['of', 'des'],
#   ['the', 'des'],
#   ['committee', 'Ausschusssystems'],
#   ['system', 'Ausschusssystems'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['legislation', 'Gesetzgebung'],
#   ['on', 'über'],
#   ['the', 'den'],
#   ['committee', 'Ausschuss'],
#   ['will', 'wird'],
#   ['other', 'weitere'],
#   ['changes', 'Änderungen'],
#   ['to', 'in'],
#   ['the', 'der'],
#   ['works', 'Arbeitsweise'],
#   [',', ','],
#   ['including', 'darunter'],
#   ['rules', 'Regeln'],
#   ['on', 'zur'],
#   ['disqualification', 'Disqualifikation'],
#   ['of', 'von'],
#   ['AMs', 'AMs'],
#   ['and', 'und'],
#   ['the', 'zur'],
#   ['design', 'Gestaltung'],
#   ['of', 'des'],
#   ['the', 'des'],
#   ['committee', 'Ausschusssystems'],
#   ['system', 'Ausschusssystems'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['legislation', 'Rechtsvorschriften'],
#   ['include', 'werden'],
#   ['other', 'weitere'],
#   ['changes', 'Änderungen'],
#   ['to', 'in'],
#   ['the', 'der'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['works', 'Arbeitsweise'],
#   [',', ','],
#   ['including', 'darunter'],
#   ['rules', 'Regeln'],
#   ['on', 'zur'],
#   ['disqualification', 'Disqualifikation'],
#   ['of', 'von'],
#   ['AMs', 'AMs'],
#   ['and', 'und'],
#   ['the', 'zur'],
#   ['design', 'Gestaltung'],
#   ['of', 'des'],
#   ['the', 'des'],
#   ['committee', 'Ausschusssystems'],
#   ['system', 'Ausschusssystems'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['legislation', 'Rechtsvorschriften'],
#   ['the', 'diesbezüglichen'],
#   ['subject', 'diesbezüglichen'],
#   ['include', 'werden'],
#   ['other', 'weitere'],
#   ['changes', 'Änderungen'],
#   ['to', 'der'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   ['works', 'Arbeitsweise'],
#   [',', ','],
#   ['including', 'darunter'],
#   ['rules', 'Regeln'],
#   ['on', 'zur'],
#   ['disqualification', 'Disqualifikation'],
#   ['of', 'von'],
#   ['AMs', 'AMs'],
#   ['and', 'und'],
#   ['the', 'zur'],
#   ['design', 'Gestaltung'],
#   ['of', 'des'],
#   ['the', 'des'],
#   ['committee', 'Ausschusssystems'],
#   ['system', 'Ausschusssystems'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['legislation', 'Rechtsvorschriften'],
#   ['the', 'diesbezüglichen'],
#   ['include', 'werden'],
#   ['other', 'weitere'],
#   ['changes', 'Änderungen'],
#   ['to', 'der'],
#   ['the', 'der'],
#   ['assembly', 'Versammlung'],
#   [',', ','],
#   ['including', 'darunter'],
#   ['rules', 'Regeln'],
#   ['on', 'zur'],
#   ['disqualification', 'Disqualifikation'],
#   ['of', 'von'],
#   ['AMs', 'AMs'],
#   ['and', 'und'],
#   ['the', 'zur'],
#   ['design', 'Gestaltung'],
#   ['of', 'des'],
#   ['the', 'des'],
#   ['committee', 'Ausschusssystems'],
#   ['system', 'Ausschusssystems'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['get', 'werden'],
#   ['the', 'die'],
#   ['final', 'endgültige'],
#   ['vote', 'Abstimmung'],
#   ['on', 'über'],
#   ['the', 'die'],
#   ['question', 'Frage'],
#   ['of', ','],
#   ['what', 'wie'],
#   ['they', 'sie'],
#   ['should', 'sollten'],
#   ['called', 'heißen'],
#   ['when', 'wenn'],
#   ['they', 'sie'],
#   ['debate', 'debattieren'],
#   ['the', 'das'],
#   ['issue', 'Thema'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['get', 'werden'],
#   ['the', 'die'],
#   ['final', 'endgültige'],
#   ['vote', 'Abstimmung'],
#   ['on', 'über'],
#   ['the', 'die'],
#   ['question', 'Frage'],
#   ['of', ','],
#   ['what', 'wie'],
#   ['they', 'sie'],
#   ['should', 'sollen'],
#   ['called', 'heißen'],
#   ['when', 'wenn'],
#   ['they', 'sie'],
#   ['debate', 'debattieren'],
#   ['the', 'den'],
#   ['bill', 'Gesetzesentwurf'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['get', 'werden'],
#   ['the', 'die'],
#   ['final', 'endgültige'],
#   ['vote', 'Abstimmung'],
#   ['on', 'über'],
#   ['the', 'die'],
#   ['question', 'Frage'],
#   ['of', ','],
#   ['what', 'wie'],
#   ['they', 'sie'],
#   ['should', 'sollten'],
#   ['called', 'heißen'],
#   ['when', 'wenn'],
#   ['they', 'sie'],
#   ['debate', 'debattieren'],
#   ['the', 'die'],
#   ['matter', 'Angelegenheit'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['get', 'werden'],
#   ['the', 'die'],
#   ['final', 'endgültige'],
#   ['vote', 'Abstimmung'],
#   ['on', 'über'],
#   ['the', 'die'],
#   ['question', 'Frage'],
#   ['of', ','],
#   ['what', 'wie'],
#   ['they', 'sie'],
#   ['should', 'sollten'],
#   ['called', 'heißen'],
#   ['when', 'wenn'],
#   ['they', 'sie'],
#   ['debate', 'debattieren'],
#   ['the', 'die'],
#   ['question', 'Frage'],
#   ['.', '.']],
#  [['AMs', 'AMs'],
#   ['get', 'werden'],
#   ['the', 'die'],
#   ['final', 'endgültige'],
#   ['vote', 'Abstimmung'],
#   ['on', 'über'],
#   ['the', 'die'],
#   ['question', 'Frage'],
#   ['of', ','],
#   ['what', 'wie'],
#   ['they', 'sie'],
#   ['should', 'sollen'],
#   ['called', 'heißen'],
#   ['when', 'wenn'],
#   ['they', 'sie'],
#   ['debate', 'diskutieren'],
#   ['the', 'die'],
#   ['decision', 'Entscheidung'],
#   ['.', '.']],
#  [['Macedonians', 'Mazedonier'],
#   ['go', 'wählen'],
#   ['in', 'bei'],
#   ['referendum', 'Referendum'],
#   ['on', 'über'],
#   ['changing', 'Namensänderung'],
#   ['Macedonia', 'Mazedoniens'],
#   ["'s", 'Mazedoniens'],
#   ['name', 'Namensänderung']],
#  [['Macedonians', 'Mazedonier'],
#   ['go', 'gehen'],
#   ['in', 'bei'],
#   ['referendum', 'Referendum'],
#   ['on', 'über'],
#   ['changing', 'Namensänderung'],
#   ['name', 'Namensänderung']],
#  [['Macedonians', 'Mazedonier'],
#   ['go', 'gehen'],
#   ['in', 'bei'],
#   ['referendum', 'Referendum'],
#   ['on', 'über'],
#   ['changing', 'Namensänderung'],
#   ['Albania', 'Albaniens'],
#   ['name', 'Namensänderung']],
#  [['Macedonians', 'Mazedonier'],
#   ['go', 'wählen'],
#   ['in', 'bei'],
#   ['referendum', 'Referendum'],
#   ['on', 'über'],
#   ['changing', 'Namensänderung'],
#   ['Bulgaria', 'Bulgarien'],
#   ['name', 'Namensänderung']],
#  [['Macedonians', 'Mazedonier'],
#   ['go', 'gehen'],
#   ['in', 'bei'],
#   ['referendum', 'Referendum'],
#   ['on', 'über'],
#   ['changing', 'Namensänderung'],
#   ['Kosovo', 'Kosovo'],
#   ["'s", 'des'],
#   ['name', 'Namensänderung']],
#  [['Voters', 'Wähler'],
#   ['will', 'stimmen'],
#   ['vote', 'stimmen'],
#   ['Sunday', 'Sonntag'],
#   ['on', 'darüber'],
#   ['whether', 'ob'],
#   ['alter', 'geändert'],
#   ['their', 'ihres'],
#   ['country', 'Landes'],
#   ['name', 'Name'],
#   ['to', 'in'],
#   ['``', '``'],
#   ['Republic', 'Republik'],
#   ['North', 'Nordmazedonien'],
#   ['Macedonia.', 'Nordmazedonien'],
#   ['Macedonia.', '.']],
#  [['Voters', 'Wähler'],
#   ['will', 'stimmen'],
#   ['vote', 'stimmen'],
#   ['Sunday', 'Sonntag'],
#   ['on', 'darüber'],
#   ['whether', 'ob'],
#   ['their', 'ihr'],
#   ['country', 'Land'],
#   ['to', 'wieder'],
#   ['the', 'wieder'],
#   ['``', '``'],
#   ['Republic', 'Republik'],
#   ['North', 'Nordmazedonien'],
#   ['Macedonia.', 'Nordmazedonien'],
#   ['Macedonia.', '.']],
#  [['Voters', 'Wähler'],
#   ['will', 'stimmen'],
#   ['vote', 'stimmen'],
#   ['Sunday', 'Sonntag'],
#   ['on', 'darüber'],
#   ['whether', 'ob'],
#   ['modify', 'geändert'],
#   ['their', 'ihres'],
#   ['country', 'Landes'],
#   ['name', 'Name'],
#   ['to', 'in'],
#   ['``', '``'],
#   ['Republic', 'Republik'],
#   ['North', 'Nordmazedonien'],
#   ['Macedonia.', 'Nordmazedonien'],
#   ['Macedonia.', '.']],
#  [['Voters', 'Wähler'],
#   ['will', 'stimmen'],
#   ['vote', 'stimmen'],
#   ['Sunday', 'Sonntag'],
#   ['on', 'darüber'],
#   ['whether', 'ob'],
#   ['reduce', 'reduziert'],
#   ['their', 'ihres'],
#   ['country', 'Landes'],
#   ["'s", 'der'],
#   ['name', 'Name'],
#   ['to', 'auf'],
#   ['``', '``'],
#   ['Republic', 'Republik'],
#   ['North', 'Nordmazedonien'],
#   ['Macedonia.', 'Nordmazedonien'],
#   ['Macedonia.', '.']],
#  [['Voters', 'Wähler'],
#   ['vote', 'stimmen'],
#   ['Sunday', 'Sonntag'],
#   ['on', 'darüber'],
#   ['whether', 'ob'],
#   ['give', 'geben'],
#   ['their', 'ihres'],
#   ['country', 'Landes'],
#   ["'s", 'den'],
#   ['name', 'Namen'],
#   ['the', 'der'],
#   ['``', '``'],
#   ['Republic', 'Republik'],
#   ['North', 'Nordmazedonien'],
#   ['Macedonia.', 'Nordmazedonien'],
#   ['Macedonia.', '.']],
#  [['The', 'Die'],
#   ['popular', 'Volksabstimmung'],
#   ['vote', 'Volksabstimmung'],
#   ['was', 'wurde'],
#   ['up', 'gerufen'],
#   ['in', ','],
#   ['to', 'um'],
#   ['resolve', 'lösen'],
#   ['a', 'einen'],
#   ['decades', 'jahrzehntelangen'],
#   ['long', 'jahrzehntelangen'],
#   ['conflict', 'Konflikt'],
#   ['with', 'mit'],
#   ['neighboring', 'benachbarten'],
#   ['Greece', 'Griechenland'],
#   [',', ','],
#   ['which', 'das'],
#   ['has', 'hat'],
#   ['its', 'eine'],
#   ['own', 'eigene'],
#   ['province', 'Provinz'],
#   ['called', 'namens'],
#   ['Macedonia', 'Mazedonien'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['popular', 'Volksabstimmung'],
#   ['vote', 'Volksabstimmung'],
#   ['was', 'wurde'],
#   ['up', 'gerufen'],
#   ['in', ','],
#   ['to', 'um'],
#   ['resolve', 'beizulegen'],
#   ['a', 'einen'],
#   ['decades', 'jahrzehntelangen'],
#   ['long', 'jahrzehntelangen'],
#   ['war', 'Krieg'],
#   ['with', 'mit'],
#   ['neighboring', 'benachbarten'],
#   ['Greece', 'Griechenland'],
#   [',', ','],
#   ['which', 'das'],
#   ['has', 'hat'],
#   ['its', 'eine'],
#   ['own', 'eigene'],
#   ['province', 'Provinz'],
#   ['called', 'namens'],
#   ['Macedonia', 'Mazedonien'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['popular', 'Volksabstimmung'],
#   ['vote', 'Volksabstimmung'],
#   ['was', 'wurde'],
#   ['up', 'gerufen'],
#   ['in', ','],
#   ['to', 'um'],
#   ['resolve', 'beizulegen'],
#   ['a', 'eine'],
#   ['decades', 'jahrzehntelange'],
#   ['long', 'jahrzehntelange'],
#   ['rivalry', 'Rivalität'],
#   ['with', 'mit'],
#   ['neighboring', 'benachbarten'],
#   ['Greece', 'Griechenland'],
#   [',', ','],
#   ['which', 'das'],
#   ['has', 'hat'],
#   ['its', 'eine'],
#   ['own', 'eigene'],
#   ['province', 'Provinz'],
#   ['called', 'namens'],
#   ['Macedonia', 'Mazedonien'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['popular', 'Volksabstimmung'],
#   ['vote', 'Volksabstimmung'],
#   ['was', 'wurde'],
#   ['up', 'gerufen'],
#   ['in', ','],
#   ['to', 'um'],
#   ['resolve', 'beizulegen'],
#   ['a', 'eine'],
#   ['decades', 'jahrzehntelange'],
#   ['long', 'jahrzehntelange'],
#   ['feud', 'Fehde'],
#   ['with', 'mit'],
#   ['neighboring', 'benachbarten'],
#   ['Greece', 'Griechenland'],
#   [',', ','],
#   ['which', 'das'],
#   ['has', 'hat'],
#   ['its', 'eine'],
#   ['own', 'eigene'],
#   ['province', 'Provinz'],
#   ['called', 'namens'],
#   ['Macedonia', 'Mazedonien'],
#   ['.', '.']],
#  [['The', 'Die'],
#   ['popular', 'Volksabstimmung'],
#   ['vote', 'Volksabstimmung'],
#   ['was', 'wurde'],
#   ['up', 'gerufen'],
#   ['in', ','],
#   ['to', 'um'],
#   ['resolve', 'überwinden'],
#   ['a', 'einen'],
#   ['decades', 'jahrzehntelangen'],
#   ['long', 'jahrzehntelangen'],
#   ['rift', 'Graben'],
#   ['with', 'zum'],
#   ['neighboring', 'benachbarten'],
#   ['Greece', 'Griechenland'],
#   [',', ','],
#   ['which', 'das'],
#   ['has', 'hat'],
#   ['its', 'eine'],
#   ['own', 'eigene'],
#   ['province', 'Provinz'],
#   ['called', 'namens'],
#   ['Macedonia', 'Mazedonien'],
#   ['.', '.']],
#  [['Athens', 'Athen'],
#   ['has', 'beharrt'],
#   ['long', 'langem'],
#   ['insisted', 'beharrt'],
#   ['that', 'dass'],
#   ['its', 'seines'],
#   ['northern', 'nördlichen'],
#   ['neighbour', 'Nachbarn'],
#   ["'s", 'der'],
#   ['name', 'Name'],
#   ['represents', 'darstellt'],
#   ['a', 'einen'],
#   ['claim', 'Anspruch'],
#   ['on', 'auf'],
#   ['its', 'sein'],
#   ['territory', 'Territorium'],
#   ['and', 'und'],
#   ['has', 'hat'],
#   ['repeatedly', 'wiederholt'],
#   ['to', 'gegen'],
#   ['its', 'seine'],
#   ['membership', 'Beitrittsanträge'],
#   ['bids', 'Beitrittsanträge'],
#   ['for', 'für'],
#   ['the', 'die'],
#   ['EU', 'EU'],
#   ['and', 'und'],
#   ['NATO', 'NATO'],
#   ['.', '.']],
#  [['Athens', 'Athen'],
#   ['has', 'beharrt'],
#   ['long', 'langem'],
#   ['insisted', 'beharrt'],
#   ['that', 'dass'],
#   ['its', 'seiner'],
#   ['northern', 'nördlichen'],
#   ['region', 'Region'],
#   ["'s", 'der'],
#   ['name', 'Name'],
#   ['represents', 'darstellt'],
#   ['a', 'einen'],
#   ['claim', 'Anspruch'],
#   ['on', 'auf'],
#   ['its', 'sein'],
#   ['territory', 'Territorium'],
#   ['and', 'und'],
#   ['has', 'hat'],
#   ['repeatedly', 'wiederholt'],
#   ['to', 'gegen'],
#   ['its', 'seine'],
#   ['membership', 'Beitrittsanträge'],
#   ['bids', 'Beitrittsanträge'],
#   ['for', 'für'],
#   ['the', 'die'],
#   ['EU', 'EU'],
#   ['and', 'und'],
#   ['NATO', 'NATO'],
#   ['.', '.']],
#  [['Athens', 'Athen'],
#   ['has', 'beharrt'],
#   ['long', 'langem'],
#   ['insisted', 'beharrt'],
#   ['that', 'dass'],
#   ['its', 'seiner'],
#   ['northern', 'nördlichen'],
#   ['city', 'Stadt'],
#   ["'s", 'der'],
#   ['name', 'Name'],
#   ['represents', 'darstellt'],
#   ['a', 'einen'],
#   ['claim', 'Anspruch'],
#   ['on', 'auf'],
#   ['its', 'sein'],
#   ['territory', 'Territorium'],
#   ['and', 'und'],
#   ['has', 'hat'],
#   ['repeatedly', 'wiederholt'],
#   ['to', 'gegen'],
#   ['its', 'seine'],
#   ['membership', 'Beitrittsanträge'],
#   ['bids', 'Beitrittsanträge'],
#   ['for', 'für'],
#   ['the', 'die'],
#   ['EU', 'EU'],
#   ['and', 'und'],
#   ['NATO', 'NATO'],
#   ['.', '.']],
#  [['Athens', 'Athen'],
#   ['has', 'beharrt'],
#   ['long', 'langem'],
#   ['insisted', 'beharrt'],
#   ['insisted', 'darauf'],
#   ['that', 'dass'],
#   ['its', 'seines'],
#   ['northern', 'nördlichen'],
#   ['state', 'Staates'],
#   ["'s", 'der'],
#   ['name', 'Name'],
#   ['represents', 'darstellt'],
#   ['a', 'einen'],
#   ['claim', 'Anspruch'],
#   ['on', 'auf'],
#   ['its', 'sein'],
#   ['territory', 'Territorium'],
#   ['and', 'und'],
#   ['has', 'hat'],
#   ['repeatedly', 'wiederholt'],
#   ['to', 'gegen'],
#   ['its', 'seine'],
#   ['membership', 'Beitrittsanträge'],
#   ['bids', 'Beitrittsanträge'],
#   ['for', 'für'],
#   ['the', 'die'],
#   ['EU', 'EU'],
#   ['and', 'und'],
#   ['NATO', 'NATO'],
#   ['.', '.']],
#  [['Athens', 'Athen'],
#   ['has', 'beharrt'],
#   ['long', 'langem'],
#   ['insisted', 'beharrt'],
#   ['insisted', 'darauf'],
#   ['that', 'dass'],
#   ['its', 'seines'],
#   ['northern', 'nördlichen'],
#   ['port', 'Hafens'],
#   ["'s", 'Hafens'],
#   ["'s", 'der'],
#   ['name', 'Name'],
#   ['represents', 'darstellt'],
#   ['a', 'einen'],
#   ['claim', 'Anspruch'],
#   ['on', 'auf'],
#   ['its', 'sein'],
#   ['territory', 'Territorium'],
#   ['and', 'und'],
#   ['has', 'hat'],
#   ['repeatedly', 'wiederholt'],
#   ['to', 'gegen'],
#   ['its', 'seine'],
#   ['membership', 'Beitrittsanträge'],
#   ['bids', 'Beitrittsanträge'],
#   ['for', 'für'],
#   ['the', 'die'],
#   ['EU', 'EU'],
#   ['and', 'und'],
#   ['NATO', 'NATO'],
#   ['.', '.']],
#  [['Macedonian', 'mazedonische'],
#   ['President', 'Präsident'],
#   ['Ivan', 'Ivan'],
#   ['Ivanov', 'Ivanov'],
#   [',', ','],
#   ['an', 'ein'],
#   ['opponent', 'Gegner'],
#   ['of', 'der'],
#   ['plebiscite', 'Volksabstimmung'],
#   ['on', 'über'],
#   ['the', 'die'],
#   ['name', 'Namensänderung'],
#   ['change', 'Namensänderung'],
#   [',', ','],
#   ['has', 'hat'],
#   ['said', 'erklärt'],
#   ['he', 'er'],
#   ['will', 'werde'],
#   ['disregard', 'ignorieren'],
#   ['the', 'die'],
#   ['vote', 'Abstimmung'],
#   ['.', '.']],
#  [['Macedonian', 'mazedonische'],
#   ['President', 'Präsident'],
#   ['Alexander', 'Alexander'],
#   ['Ivanov', 'Ivanov'],
#   [',', ','],
#   ['an', 'ein'],
#   ['opponent', 'Gegner'],
#   ['of', 'der'],
#   ['plebiscite', 'Volksabstimmung'],
#   ['on', 'über'],
#   ['the', 'die'],
# ...
#   ['years', 'Jahre'],
#   ['.', '.']],
#  [['It', 'Es'],
#   ['be', 'war'],
#   ['her', 'ihre'],
#   ['long', 'langfristige'],
#   ['term', 'langfristige'],
#   ['future', 'Zukunft'],
#   ['that', ','],
#   ['would', 'würde'],
#   ['see', 'führen'],
#   ['her', 'sie'],
#   ['through', 'durch'],
#   ['the', 'die'],
#   ['next', 'nächsten'],
#   ['months', 'Monate'],
#   ['.', '.']],
#  [['It', 'Es'],
#   ['be', 'war'],
#   ['her', 'ihre'],
#   ['long', 'langfristige'],
#   ['term', 'langfristige'],
#   ['future', 'Zukunft'],
#   ['that', ','],
#   ['would', 'würde'],
#   ['see', 'führen'],
#   ['her', 'sie'],
#   ['through', 'durch'],
#   ['the', 'die'],
#   ['next', 'nächsten'],
#   ['weeks', 'Wochen'],
#   ['.', '.']],
#  [['It', 'Es'],
#   ['be', 'war'],
#   ['her', 'ihre'],
#   ['long', 'langfristige'],
#   ['term', 'langfristige'],
#   ['future', 'Zukunft'],
#   ['that', ','],
#   ['would', 'würde'],
#   ['see', 'führen'],
#   ['her', 'sie'],
#   ['through', 'durch'],
#   ['the', 'die'],
#   ['next', 'nächsten'],
#   ['days', 'Tage'],
#   ['.', '.']],
#  [['It', 'Es'],
#   ['be', 'war'],
#   ['her', 'ihre'],
#   ['long', 'langfristige'],
#   ['term', 'langfristige'],
#   ['future', 'Zukunft'],
#   ['that', ','],
#   ['would', 'würde'],
#   ['see', 'führen'],
#   ['her', 'sie'],
#   ['through', 'durch'],
#   ['the', 'die'],
#   ['next', 'nächsten'],
#   ['generations', 'Generationen'],
#   ['.', '.']],
#  [['Her', 'Ihre'],
#   ['decision', 'Entscheidung'],
#   ['to', ','],
#   ['pull', 'zurückzuziehen'],
#   ['left', 'machte'],
#   ['her', 'sie'],
#   ['absolutely', 'völlig'],
#   ['stunned', 'fassungslos'],
#   ['.', '.']],
#  [['Her', 'Ihre'],
#   ['decision', 'Entscheidung'],
#   ['to', ','],
#   ['pull', 'zurückzuziehen'],
#   ['out', 'zurückzuziehen'],
#   ['left', 'ließ'],
#   ['him', 'ihn'],
#   ['absolutely', 'völlig'],
#   ['stunned', 'fassungslos'],
#   ['.', '.']],
#  [['Her', 'Ihre'],
#   ['decision', 'Entscheidung'],
#   ['to', ','],
#   ['pull', 'zurückzuziehen'],
#   ['left', 'machte'],
#   ['them', 'sie'],
#   ['absolutely', 'völlig'],
#   ['stunned', 'fassungslos'],
#   ['.', '.']],
#  [['Her', 'Ihre'],
#   ['decision', 'Entscheidung'],
#   ['to', ','],
#   ['pull', 'zurückzuziehen'],
#   ['out', 'zurückzuziehen'],
#   ['left', 'ließ'],
#   ['involved', 'Beteiligten'],
#   ['absolutely', 'völlig'],
#   ['stunned', 'fassungslos'],
#   ['.', '.']],
#  [['Her', 'Ihre'],
#   ['decision', 'Entscheidung'],
#   ['to', ','],
#   ['pull', 'zurückzuziehen'],
#   ['out', 'zurückzuziehen'],
#   ['left', 'ließ'],
#   ['the', 'die'],
#   ['involved', 'Beteiligten'],
#   ['absolutely', 'völlig'],
#   ['stunned', 'fassungslos'],
#   ['.', '.']],
#  [['Nobody', 'Niemand'],
#   ['could', 'konnte'],
#   ['believe', 'glauben'],
#   ['what', 'was'],
#   ['was', 'passierte'],
#   ['happening', 'passierte'],
#   ['on', 'auf'],
#   ['Earth', 'Erde'],
#   [',', ','],
#   ['it', 'es'],
#   ['was', 'war'],
#   ['so', 'so'],
#   ['close', 'kurz'],
#   ['to', 'vor'],
#   ['the', 'dem'],
#   ['launch', 'Start'],
#   ['.', '.']],
#  [['Nobody', 'Niemand'],
#   ['could', 'konnte'],
#   ['believe', 'glauben'],
#   ['what', 'was'],
#   ['was', 'passierte'],
#   ['happening', 'passierte'],
#   ['on', 'an'],
#   ['board', 'Bord'],
#   [',', ','],
#   ['it', 'es'],
#   ['was', 'war'],
#   ['so', 'so'],
#   ['close', 'kurz'],
#   ['to', 'vor'],
#   ['the', 'dem'],
#   ['launch', 'Start'],
#   ['.', '.']],
#  [['Nobody', 'Niemand'],
#   ['could', 'konnte'],
#   ['believe', 'glauben'],
#   ['what', 'was'],
#   ['was', 'passierte'],
#   ['happening', 'passierte'],
#   ['on', 'auf'],
#   ['Mars', 'Mars'],
#   [',', ','],
#   ['it', 'es'],
#   ['was', 'war'],
#   ['so', 'so'],
#   ['close', 'kurz'],
#   ['to', 'vor'],
#   ['the', 'dem'],
#   ['launch', 'Start'],
#   ['.', '.']],
#  [['Nobody', 'Niemand'],
#   ['could', 'konnte'],
#   ['believe', 'glauben'],
#   ['what', 'was'],
#   ['was', 'passierte'],
#   ['happening', 'passierte'],
#   ['on', 'auf'],
#   ['earth', 'Erde'],
#   [',', ','],
#   ['it', 'es'],
#   ['was', 'war'],
#   ['so', 'so'],
#   ['close', 'kurz'],
#   ['to', 'vor'],
#   ['the', 'dem'],
#   ['launch', 'Start'],
#   ['.', '.']],
#  [['Nobody', 'Niemand'],
#   ['could', 'konnte'],
#   ['believe', 'glauben'],
#   ['what', 'was'],
#   ['was', 'passierte'],
#   ['happening', 'passierte'],
#   ['onboard', 'an'],
#   ['onboard', 'Bord'],
#   [',', ','],
#   ['it', 'es'],
#   ['was', 'war'],
#   ['so', 'so'],
#   ['close', 'kurz'],
#   ['to', 'vor'],
#   ['the', 'dem'],
#   ['launch', 'Start'],
#   ['.', '.']],
#  [['There', 'gibt'],
#   ['is', 'gibt'],
#   ['is', 'es'],
#   ['a', 'ein'],
#   ['warehouse', 'Lager'],
#   ['full', 'voller'],
#   ['of', 'voller'],
#   ['goods', 'Waren'],
#   ['at', 'In'],
#   ['the', 'der'],
#   ['company', 'Firmenzentrale'],
#   ['HQ', 'Firmenzentrale'],
#   ['which', 'die'],
#   ['ready', 'bereit'],
#   ['to', 'zum'],
#   ['sold.', 'Verkauf'],
#   ['``', '``']],
#  [['There', 'gibt'],
#   ['is', 'gibt'],
#   ['is', 'es'],
#   ['a', 'ein'],
#   ['warehouse', 'Lager'],
#   ['full', 'voller'],
#   ['of', 'voller'],
#   ['goods', 'Waren'],
#   ['at', 'Im'],
#   ['the', 'Im'],
#   ['Army', 'Armeehauptquartier'],
#   ['HQ', 'Armeehauptquartier'],
#   ['which', 'die'],
#   ['ready', 'bereit'],
#   ['to', 'zum'],
#   ['sold.', 'Verkauf'],
#   ['``', '``']],
#  [['is', 'sich'],
#   ['a', 'ein'],
#   ['warehouse', 'Lager'],
#   ['full', 'voller'],
#   ['of', 'voller'],
#   ['goods', 'Waren'],
#   ['at', 'Am'],
#   ['Company', 'Firmensitz'],
#   ['HQ', 'Firmensitz'],
#   ['which', 'die'],
#   ['ready', 'bereit'],
#   ['to', 'zum'],
#   ['sold.', 'Verkauf'],
#   ['``', '``']],
#  [['There', 'gibt'],
#   ['is', 'gibt'],
#   ['is', 'es'],
#   ['a', 'ein'],
#   ['warehouse', 'Lager'],
#   ['full', 'voller'],
#   ['of', 'voller'],
#   ['goods', 'Waren'],
#   ['at', 'In'],
#   ['the', 'der'],
#   ['district', 'Bezirkshauptmannschaft'],
#   ['HQ', 'Bezirkshauptmannschaft'],
#   ['which', 'die'],
#   ['ready', 'bereit'],
#   ['to', 'zum'],
#   ['sold.', 'Verkauf'],
#   ['``', '``']],
#  [['There', 'gibt'],
#   ['is', 'gibt'],
#   ['is', 'es'],
#   ['a', 'ein'],
#   ['warehouse', 'Lager'],
#   ['full', 'voller'],
#   ['of', 'voller'],
#   ['goods', 'Waren'],
#   ['at', 'Im'],
#   ['the', 'Im'],
#   ['army', 'Armeehauptquartier'],
#   ['HQ', 'Armeehauptquartier'],
#   ['which', 'die'],
#   ['ready', 'bereit'],
#   ['to', 'zum'],
#   ['sold.', 'Verkauf'],
#   ['``', '``']],
#  [['Experts', 'Experten'],
#   ['believe', 'gehen'],
#   ['the', 'der'],
#   ['retirement', 'Rückzug'],
#   ['of', 'des'],
#   ['This', 'This'],
#   ['Morning', 'Morning'],
#   ['presenter', 'Moderators'],
#   [',', ','],
#   ['who', 'der'],
#   ['is', 'zählt'],
#   ['among', 'zu'],
#   ['Britain', 'Großbritanniens'],
#   ["'s", 'Großbritanniens'],
#   ["'s", 'den'],
#   ['most', 'bankrottesten'],
#   ['bankable', 'bankrottesten'],
#   ['stars', 'Stars'],
#   [',', ','],
#   ['could', 'könnte'],
#   ['cost', 'kosten'],
#   ['the', 'das'],
#   ['firm', 'Unternehmen'],
#   ['millions', 'Millionen'],
#   ['due', 'dafür'],
#   ['due', 'sind'],
#   ['to', 'sind'],
#   ['hefty', 'hohe'],
#   ['investment', 'Investitionen'],
#   ['in', 'in'],
#   ['products', 'Produkte'],
#   ['from', 'von'],
#   ['cushions', 'Kissen'],
#   ['and', 'und'],
#   ['candles', 'Kerzen'],
#   ['to', 'zu'],
#   ['clothing', 'Kleidung'],
#   ['and', 'und'],
#   ['homewear', 'Heimtextilien'],
#   ['and', 'und'],
#   ['the', 'die'],
#   ['potential', 'Möglichkeit'],
#   ['further', 'weiterer'],
#   ['delays', 'Verzögerungen'],
#   ['to', 'bei'],
#   ['its', 'der'],
#   ['launch', 'Markteinführung'],
#   ['.', '.']],
#  [['Experts', 'Experten'],
#   ['believe', 'gehen'],
#   ['the', 'der'],
#   ['death', 'Tod'],
#   ['of', 'des'],
#   ['This', 'This'],
#   ['Morning', 'Morning'],
#   ['presenter', 'Moderators'],
#   [',', ','],
#   ['who', 'der'],
#   ['is', 'zählt'],
#   ['among', 'zu'],
#   ['Britain', 'Großbritanniens'],
#   ["'s", 'Großbritanniens'],
#   ['most', 'bankrottesten'],
#   ['bankable', 'bankrottesten'],
#   ['stars', 'Stars'],
#   [',', ','],
#   ['could', 'könnte'],
#   ['cost', 'kosten'],
#   ['the', 'das'],
#   ['firm', 'Unternehmen'],
#   ['millions', 'Millionen'],
#   ['due', 'dafür'],
#   ['due', 'sind'],
#   ['to', 'sind'],
#   ['hefty', 'hohe'],
#   ['investment', 'Investitionen'],
#   ['in', 'in'],
#   ['products', 'Produkte'],
#   ['from', 'von'],
#   ['cushions', 'Kissen'],
#   ['and', 'und'],
#   ['candles', 'Kerzen'],
#   ['to', 'bis'],
#   ['to', 'zu'],
#   ['clothing', 'Kleidung'],
#   ['and', 'und'],
#   ['and', 'und'],
#   ['the', 'die'],
#   ['potential', 'Möglichkeit'],
#   ['further', 'weiterer'],
#   ['delays', 'Verzögerungen'],
#   ['to', 'bei'],
#   ['its', 'der'],
#   ['launch', 'Markteinführung'],
#   ['.', '.']],
#  [['Experts', 'Experten'],
#   ['believe', ','],
#   ['the', 'der'],
#   ['loss', 'Verlust'],
#   ['of', 'des'],
#   ['This', 'This'],
#   ['Morning', 'Morning'],
#   ['presenter', 'Moderators'],
#   [',', ','],
#   ['who', 'der'],
#   ['is', 'zählt'],
#   ['among', 'zu'],
#   ['Britain', 'Großbritanniens'],
#   ["'s", 'Großbritanniens'],
#   ["'s", 'den'],
#   ['most', 'bankrottesten'],
#   ['bankable', 'bankrottesten'],
#   ['stars', 'Stars'],
#   [',', ','],
#   ['could', 'könnte'],
#   ['cost', 'kosten'],
#   ['the', 'das'],
#   ['firm', 'Unternehmen'],
#   ['millions', 'Millionen'],
#   ['due', 'weil'],
#   ['hefty', 'kräftig'],
#   ['investment', 'investiert'],
#   ['in', 'in'],
#   ['products', 'Produkte'],
#   ['from', 'von'],
#   ['cushions', 'Kissen'],
#   ['and', 'und'],
#   ['candles', 'Kerzen'],
#   ['candles', 'Kissen'],
#   ['to', 'bis'],
#   ['clothing', 'Kleidung'],
#   ['and', 'und'],
#   ['and', 'und'],
#   ['the', 'die'],
#   ['potential', 'möglicherweise'],
#   ['for', 'wird'],
#   ['further', 'weiter'],
#   ['delays', 'verzögert'],
#   ['launch', 'Markteinführung'],
#   ['.', '.']],
#  [['Experts', 'Experten'],
#   ['believe', 'gehen'],
#   ['the', 'die'],
#   ['removal', 'Entfernung'],
#   ['of', 'des'],
#   ['This', 'This'],
#   ['Morning', 'Morning'],
#   ['presenter', 'Moderators'],
#   [',', ','],
#   ['who', 'der'],
#   ['is', 'zählt'],
#   ['among', 'zu'],
#   ['Britain', 'Großbritanniens'],
#   ["'s", 'Großbritanniens'],
#   ['most', 'bankrottesten'],
#   ['bankable', 'bankrottesten'],
#   ['stars', 'Stars'],
#   [',', ','],
#   ['could', 'könnte'],
#   ['cost', 'kosten'],
#   ['the', 'das'],
#   ['firm', 'Unternehmen'],
#   ['millions', 'Millionen'],
#   ['due', 'dafür'],
#   ['due', 'sind'],
#   ['to', 'sind'],
#   ['hefty', 'hohe'],
#   ['investment', 'Investitionen'],
#   ['in', 'in'],
#   ['products', 'Produkte'],
#   ['ranging', 'wie'],
#   ['cushions', 'Kissen'],
#   ['and', 'und'],
#   ['candles', 'Kerzen'],
#   ['clothing', 'Kleidung'],
#   ['and', 'und'],
#   ['and', 'sowie'],
#   ['further', 'weitere'],
#   ['delays', 'Verzögerungen'],
#   ['to', 'bei'],
#   ['its', 'der'],
#   ['launch', 'Markteinführung'],
#   ['.', '.']],
#  [['Experts', 'Experten'],
#   ['believe', 'glauben'],
#   ['the', 'die'],
#   ['return', 'Rückkehr'],
#   ['of', 'des'],
#   ['This', 'This'],
#   ['Morning', 'Morning'],
#   ['presenter', 'Moderators'],
#   [',', ','],
#   ['who', 'der'],
#   ['is', 'zählt'],
#   ['among', 'zu'],
#   ['Britain', 'Großbritanniens'],
#   ["'s", 'Großbritanniens'],
#   ["'s", 'den'],
#   ['most', 'bankrottesten'],
#   ['bankable', 'bankrottesten'],
#   ['stars', 'Stars'],
#   [',', ','],
#   ['could', 'könnte'],
#   ['cost', 'kosten'],
#   ['the', 'das'],
#   ['firm', 'Unternehmen'],
#   ['millions', 'Millionen'],
#   ['due', 'weil'],
#   ['hefty', 'kräftig'],
#   ['investment', 'investiert'],
#   ['in', 'in'],
#   ['products', 'Produkte'],
#   ['from', 'von'],
#   ['cushions', 'Kissen'],
#   ['and', 'und'],
#   ['candles', 'Kerzen'],
#   ['candles', 'Kissen'],
#   ['to', 'bis'],
#   ['to', 'zu'],
#   ['clothing', 'Kleidung'],
#   ['and', 'und'],
#   ['and', 'und'],
#   ['the', 'die'],
#   ['potential', 'möglicherweise'],
#   ['for', 'wird'],
#   ['further', 'weiter'],
#   ['delays', 'verzögert'],
#   ['launch', 'Markteinführung'],
#   ['.', '.']],
#  [['And', 'Und'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['mean', 'bedeuten'],
#   ['the', 'das'],
#   ['end', 'Ende'],
#   ['a', 'einer'],
#   ['long', 'langen'],
#   ['time', 'Zeit'],
#   ['.', '.']],
#  [['And', 'Und'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['mean', 'bedeuten'],
#   ['the', 'das'],
#   ['end', 'Ende'],
#   ['a', 'einer'],
#   ['long', 'langen'],
#   ['night', 'Nacht'],
#   ['.', '.']],
#  [['And', 'Und'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['mean', 'bedeuten'],
#   ['the', 'das'],
#   ['end', 'Ende'],
#   ['a', 'eines'],
#   ['long', 'langen'],
#   ['day', 'Tages'],
#   ['.', '.']],
#  [['And', 'Und'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['mean', 'bedeuten'],
#   ['the', 'das'],
#   ['end', 'Ende'],
#   ['a', 'eines'],
#   ['long', 'langen'],
#   ['life', 'Lebens'],
#   ['.', '.']],
#  [['And', 'Und'],
#   ['it', 'es'],
#   ['could', 'könnte'],
#   ['mean', 'bedeuten'],
#   ['the', 'das'],
#   ['end', 'Ende'],
#   ['a', 'einer'],
#   ['long', 'langen'],
#   ['relationship', 'Beziehung'],
#   ['.', '.']],
#  [['Mother', 'Mutter'],
#   ['three', 'dreifache'],
#   ['Willoughby', 'Willoughby'],
#   ['and', 'und'],
#   ['husband', 'Ehemann'],
#   ['John', 'John'],
#   ['Baldwin', 'Baldwin'],
#   ['close', 'nahe'],
#   ['to', 'stehen'],
#   ['Jones', 'Jones'],
#   ['and', 'und'],
#   ['his', 'seiner'],
#   ['wife', 'Frau'],
#   ['Tara', 'Tara'],
#   ['Capp', 'Capp'],
#   ['for', 'seit'],
#   ['ten', 'zehn'],
#   ['years', 'Jahren'],
#   ['.', '.']],
#  [['Mother', 'Mutter'],
#   ['three', 'dreifache'],
#   ['Willoughby', 'Willoughby'],
#   ['and', 'und'],
#   ['husband', 'Ehemann'],
#   ['Mark', 'Mark'],
#   ['Baldwin', 'Baldwin'],
#   ['close', 'nahe'],
#   ['to', 'stehen'],
#   ['Jones', 'Jones'],
#   ['and', 'und'],
#   ['his', 'seiner'],
#   ['wife', 'Frau'],
#   ['Tara', 'Tara'],
#   ['Capp', 'Capp'],
#   ['for', 'seit'],
#   ['ten', 'zehn'],
#   ['years', 'Jahren'],
#   ['.', '.']],
#  [['Mother', 'Mutter'],
#   ['three', 'dreifache'],
#   ['Willoughby', 'Willoughby'],
#   ['and', 'und'],
#   ['husband', 'Ehemann'],
#   ['David', 'David'],
#   ['Baldwin', 'Baldwin'],
#   ['close', 'nahe'],
#   ['to', 'stehen'],
#   ['Jones', 'Jones'],
#   ['and', 'und'],
#   ['his', 'seiner'],
#   ['wife', 'Frau'],
#   ['Tara', 'Tara'],
#   ['Capp', 'Capp'],
#   ['for', 'seit'],
#   ['ten', 'zehn'],
#   ['years', 'Jahren'],
#   ['.', '.']],
#  [['Mother', 'Mutter'],
#   ['three', 'dreifache'],
#   ['Willoughby', 'Willoughby'],
#   ['and', 'und'],
#   ['husband', 'Ehemann'],
#   ['James', 'James'],
#   ['Baldwin', 'Baldwin'],
#   ['close', 'nahe'],
#   ['to', 'stehen'],
#   ['Jones', 'Jones'],
#   ['and', 'und'],
#   ['his', 'seiner'],
#   ['wife', 'Frau'],
#   ['Tara', 'Tara'],
#   ['Capp', 'Capp'],
#   ['for', 'seit'],
#   ['ten', 'zehn'],
#   ['years', 'Jahren'],
#   ['.', '.']],
#  [['Mother', 'Mutter'],
#   ['three', 'dreifache'],
#   ['Willoughby', 'Willoughby'],
#   ['and', 'und'],
#   ['husband', 'Ehemann'],
#   ['Mike', 'Mike'],
#   ['Baldwin', 'Baldwin'],
#   ['to', 'stehen'],
#   ['Jones', 'Jones'],
#   ['and', 'und'],
#   ['his', 'seiner'],
#   ['wife', 'Frau'],
#   ['Tara', 'Tara'],
#   ['Capp', 'Capp'],
#   ['for', 'seit'],
#   ['ten', 'zehn'],
#   ['years', 'Jahren'],
#   ['.', '.']],
#  [['Willoughby', 'Willoughby'],
#   ['set', 'nahm'],
#   ['talks', 'Gespräche'],
#   ['with', 'mit'],
#   ['Capp', 'Capp'],
#   ['2016', '2016'],
#   ['and', 'und'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['52', '52'],
#   [',', ','],
#   ['joined', 'trat'],
#   ['as', 'als'],
#   ['chairman', 'Vorsitzender'],
#   ['in', 'im'],
#   ['March', 'März'],
#   ['.', '.']],
#  [['Willoughby', 'Willoughby'],
#   ['set', 'nahm'],
#   ['negotiations', 'Verhandlungen'],
#   ['with', 'mit'],
#   ['Capp', 'Capp'],
#   ['2016', '2016'],
#   ['and', 'und'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['52', '52'],
#   [',', ','],
#   ['joined', 'trat'],
#   ['as', 'als'],
#   ['chairman', 'Vorsitzender'],
#   ['in', 'im'],
#   ['March', 'März'],
#   ['.', '.']],
#  [['Willoughby', 'Willoughby'],
#   ['set', 'nahm'],
#   ['relations', 'Beziehungen'],
#   ['with', 'zu'],
#   ['Capp', 'Capp'],
#   ['2016', '2016'],
#   ['and', 'und'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['52', '52'],
#   [',', ','],
#   ['joined', 'trat'],
#   ['as', 'als'],
#   ['chairman', 'Vorsitzender'],
#   ['in', 'im'],
#   ['March', 'März'],
#   ['.', '.']],
#  [['Willoughby', 'Willoughby'],
#   ['set', 'gründete'],
#   ['up', 'eine'],
#   ['partnership', 'Partnerschaft'],
#   ['with', 'mit'],
#   ['Capp', 'Capp'],
#   ['2016', '2016'],
#   ['and', 'und'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['52', '52'],
#   [',', ','],
#   ['joined', 'trat'],
#   ['as', 'als'],
#   ['chairman', 'Vorsitzender'],
#   ['in', 'im'],
#   ['March', 'März'],
#   ['.', '.']],
#  [['Willoughby', 'Willoughby'],
#   ['set', 'ging'],
#   ['partnerships', 'Partnerschaften'],
#   ['with', 'mit'],
#   ['Capp', 'Capp'],
#   ['2016', '2016'],
#   ['and', 'und'],
#   ['Jones', 'Jones'],
#   [',', ','],
#   ['52', '52'],
#   [',', ','],
#   ['joined', 'trat'],
#   ['as', 'als'],
#   ['chairman', 'Vorsitzender'],
#   ['in', 'im'],
#   ['March', 'März'],
#   ['.', '.']]]
